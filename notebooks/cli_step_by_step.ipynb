# %% [markdown]
# # Step by step Bragg edge fitting with iBeatles

# %%
import logging
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from scipy.ndimage import gaussian_filter1d
from ibeatles.app.cli import load_data, load_config
from ibeatles.core.config import OutputFileConfig
from ibeatles.core.processing.normalization import normalize_data
from ibeatles.core.fitting.binning import get_bin_coordinates, get_bin_transmission
from ibeatles.core.material import get_initial_bragg_edge_lambda
from ibeatles.core.fitting.kropff.fitting import fit_bragg_edge_single_pass
from ibeatles.core.strain.mapping import calculate_strain_mapping
from ibeatles.core.strain.visualization import (
    plot_strain_map_overlay,
    plot_fitting_results_grid,
)
from ibeatles.core.strain.export import save_analysis_results

# %%
# Set up a custom handler and formatter
handler = logging.StreamHandler()
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)
handler.setLevel(logging.INFO)

# Get the root logger and attach the handler
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [handler]  # Replace existing handlers with the custom handler

# %% [markdown]
# ## Data Loading

# %%
# load config
logging.info("Loading config file")
config_file = "../tests/data/json/demo_config.json"
config = load_config(config_file)
logging.info(config)

# load data
logging.info("Loading data")
data_dict = load_data(config)
logging.info(data_dict.keys())
# make local var for raw data, open beam and spectra data
raw_data_dict = data_dict["raw_data"]
open_beam_dict = data_dict["open_beam"]
spectra_dict = data_dict["spectra"]
logging.info(raw_data_dict.keys())
logging.info(open_beam_dict.keys())
logging.info(spectra_dict.keys())
# Out:
# 2024-11-08 15:10:48,851 - INFO - Loading config file
# 2024-11-08 15:10:48,851 - INFO - Loading configuration: ../tests/data/json/demo_config.json
# 2024-11-08 15:10:48,853 - WARNING - Using user-provided d0. This overrides the value calculated from material properties.
# 2024-11-08 15:10:48,853 - INFO - raw_data=RawData(raw_data_dir=PosixPath('/Users/8cz/github.com/iBeatles/tests/data/ibeatles_data/SNS/SNAP/IPTS-26171/shared/mcp_transfer/Inconel_Sample'), raw_data_extension='.fits') open_beam=OpenBeamData(open_beam_data_dir=PosixPath('/Users/8cz/github.com/iBeatles/tests/data/ibeatles_data/SNS/SNAP/IPTS-26171/shared/mcp_transfer/Inconel_OB'), open_beam_data_extension='.fits') spectra_file_path=None normalization=NormalizationConfig(sample_background=[SampleBackground(x0=10, y0=10, width=50, height=50), SampleBackground(x0=0, y0=0, width=3, height=3)], moving_average=MovingAverage(active=True, dimension='2D', size=KernelSize(y=3, x=3), type=<KernelType.box: 'Box'>), processing_order=<ProcessOrder.moving_average_normalization: 'Moving average, Normalization'>) analysis=AnalysisConfig(material=Material(element='Ni', custom_material=None), pixel_binning=PixelBinning(x0=140, y0=154, width=184, height=150, bins_size=10), fitting=FittingConfig(lambda_min=2.4e-10, lambda_max=2.8e-10, threshold_finder=ThresholdFinder(method='Sliding Average', threshold_width=5), fitting_criteria=FittingCriteria(lambda_hkl={'use': True, 'value': 0.01}, tau={'use': False, 'value': 0.01}, sigma={'use': False, 'value': 0.01}), rejection_criteria=RejectionCriteria(bragg_peak_lambda_min={'use': True, 'value': 0.0}, bragg_peak_lambda_max={'use': True, 'value': 10.0})), strain_mapping=StrainMapping(d0=3.52, quality_threshold=0.8, visualization=StrainVisualization(interpolation_method=<InterpolationMethod.NEAREST: 'nearest'>, colormap='viridis', alpha=0.5, display_fit_quality=True), output_file_config=OutputFileConfig(strain_map_format='png', fitting_grid_format='pdf', figure_dpi=300, csv_format=CsvFormat(delimiter=',', include_metadata_header=True, metadata_comment_char='#', na_rep='null')), save_intermediate_results=False), distance_source_detector_in_m=19.855, detector_offset_in_us=5000.0) output={'normalized_data_dir': PosixPath('/Users/8cz/tmp/ibeatles_dev/normalized'), 'analysis_results_dir': PosixPath('/Users/8cz/tmp/ibeatles_dev/analysis'), 'strain_results_dir': PosixPath('/Users/8cz/tmp/ibeatles_dev/strain')}
# 2024-11-08 15:10:48,853 - INFO - Loading data
# 2024-11-08 15:10:48,854 - INFO - Loading data...
# 2024-11-08 15:10:56,877 - INFO - dict_keys(['raw_data', 'open_beam', 'spectra'])
# 2024-11-08 15:10:56,878 - INFO - dict_keys(['data', 'metadata', 'file_list', 'folder', 'size'])
# 2024-11-08 15:10:56,878 - INFO - dict_keys(['data', 'metadata', 'file_list', 'folder', 'size'])
# 2024-11-08 15:10:56,878 - INFO - dict_keys(['filename', 'short_filename', 'tof_array', 'counts_array', 'lambda_array'])

# %% [markdown]
# quick sanity check of the spectrum data

# %%
# plot the overall spectra (lambda vs. counts)
lambda_array = spectra_dict["lambda_array"]
counts_array = spectra_dict["counts_array"]

plt.plot(lambda_array, counts_array)
plt.xlabel("Wavelength (m)")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ## Data normalization
#
# We will be using NeuNorm (ibeatles provide a wrapper for NeuNorm) to perform the normalization

# %%
normalized_data, output_path = normalize_data(
    sample_data=raw_data_dict["data"],
    ob_data=open_beam_dict["data"],
    time_spectra=spectra_dict,
    config=config,
    output_folder=config.output["normalized_data_dir"],
)
# Out:
# 2024-11-08 15:10:56,961 - INFO - Starting normalization process
# Loading sample:   0%|          | 0/1435 [00:00<?, ?it/s]
# Loading ob:   0%|          | 0/1435 [00:00<?, ?it/s]
# 2024-11-08 15:10:57,499 - INFO - Applying moving average
# 2024-11-08 15:11:13,655 - INFO - Performing normalization
# 2024-11-08 15:11:15,280 - INFO - Copied time spectra file to /Users/8cz/tmp/ibeatles_dev/normalized/Inconel_Sample_normalized/20210910_Run_52256_InconelPowder_0008_0646026_Spectra.txt

# %% [markdown]
# Sanity check of the normalized data

# %%
# display original and clipped image
img = normalized_data[0].T
img_clipped = np.array(img)
img_clipped[img > 1.0] = np.nan

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(img, cmap="viridis")
ax[0].set_title("Original Image")
# add colorbar
cbar = plt.colorbar(ax[0].imshow(img, cmap="viridis"), ax=ax[0])
ax[1].imshow(img_clipped, cmap="viridis")
ax[1].set_title("Clipped Image")
# add colorbar
cbar = plt.colorbar(ax[1].imshow(img_clipped, cmap="viridis"), ax=ax[1])

plt.show()

# %% [markdown]
# compute the cumulative distribution for the intensity (transmission) values

# %%
# compute the histogram
hist, bin_edges = np.histogram(img.flatten(), bins=1000, density=True)

# compute the cumulative distribution
cdf = np.cumsum(hist)

# plot the histogram and the cumulative distribution
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].plot(bin_edges[:-1], hist)
ax[0].set_title("Histogram")
ax[0].set_xlabel("Intensity")
ax[0].set_ylabel("Frequency")

ax[1].plot(bin_edges[:-1], cdf)
ax[1].set_title("Cumulative Distribution")
ax[1].set_xlabel("Intensity")
ax[1].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# ## Kropff fitting to locate the Bragg edge

# %%
logging.info(config.analysis.pixel_binning)
# Out:
# 2024-11-08 15:11:15,620 - INFO - x0=140 y0=154 width=184 height=150 bins_size=10

# %%
bins = get_bin_coordinates(
    image_shape=normalized_data[0].shape,
    **config.analysis.pixel_binning.model_dump(),  # to dict for unpacking
)

# %% [markdown]
# Get transmission profile for each bin

# %%
wavelengths = spectra_dict["lambda_array"]
lambda_range = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max

bin_transmission = {}

for i, bin_coord in enumerate(bins):
    wavelengths_bin, transmission_bin = get_bin_transmission(
        images=normalized_data,
        wavelengths=wavelengths,
        bin_coords=bin_coord,
        lambda_range=None,
    )
    bin_transmission[str(i)] = {
        "wavelengths": wavelengths_bin,
        "transmission": transmission_bin,
        "coordinates": bin_coord,
    }

# %% [markdown]
# visual inspection of the transmission profiles

# %%
# Normalize the keys for colormap
keys = list(bin_transmission.keys())
norm = mcolors.Normalize(vmin=min(keys), vmax=max(keys))
cmap = cm.viridis

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Plot each curve with color from colormap
for key, value in bin_transmission.items():
    key = int(key)  # Convert key to integer
    color = cmap(norm(key))  # Map the key to a color
    ax.plot(
        value["wavelengths"],
        value["transmission"],
        color=color,
        linewidth=0.5,
        alpha=0.5,
    )

# Label axes
ax.set_xlabel("Wavelength (m)")
ax.set_ylabel("Transmission")

# Add color bar with label
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Required for ScalarMappable
cbar = fig.colorbar(sm, ax=ax)  # Associate color bar with the current axis
cbar.set_label("Bin ID")  # Replace with the appropriate label for your keys

plt.show()

# %% [markdown]
# Now let's isolate one bin and perform a manual fitting

# %%
bin_data_0 = bin_transmission["0"]
wavelengths_m = bin_data_0["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data_0["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = (
    config.analysis.fitting.lambda_min,
    config.analysis.fitting.lambda_max,
)
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (
    wavelengths_angstrom < lambda_max_angstrom
)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=initial_parameters,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# top one shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color="green", alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color="red", linestyle="--")
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# bottom one shows the fitting range
fit_result.plot_fit(ax=ax[1])

plt.show()

# print the fitting result
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>395</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.00809122</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 4.2811e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1964.63769</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1941.69089</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95054661</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.56732929</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.54851446</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.97470754</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.28303060</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.62036567</td><td style='text-align:left'>2.491702875545156</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00891793</td><td style='text-align:left'>0.01</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.00100087</td><td style='text-align:left'>0.01</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table>

# %% [markdown]
# when the data is (relatively) clean with sufficient SNR, the default single pass fitting will work.
#
# However things becomes slightly more complicated when the data is noisy or when the SNR is low, for instance:

# %%
bin_data_0 = bin_transmission["1"]
wavelengths_m = bin_data_0["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data_0["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = (
    config.analysis.fitting.lambda_min,
    config.analysis.fitting.lambda_max,
)
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (
    wavelengths_angstrom < lambda_max_angstrom
)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=initial_parameters,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# top one shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color="green", alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color="red", linestyle="--")
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# bottom one shows the fitting range
# fit_result.plot_fit(ax=ax[1])
ax[1].plot(wavelengths_fitting_angstrom, transmission_fitting)

plt.show()

# print the fitting result
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-11-08 15:11:19,782 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.

# %% [markdown]
# This data is not extremely noisy, but the high frequency noise is making the fitting difficult. Therefore we will have to use a two step fitting approach to deal with this issue.
# - step 1: use low-pass filter (Gaussian) to adaptively reach a smooth representation of the data such that an initial guess can be made
# - step 2: use the initial guess to perform a single pass fitting with the raw data

# %%
bin_data = bin_transmission["1"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = (
    config.analysis.fitting.lambda_min,
    config.analysis.fitting.lambda_max,
)
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (
    wavelengths_angstrom < lambda_max_angstrom
)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color="green", alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color="red", linestyle="--")
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(
    wavelengths_fitting_angstrom,
    transmission_fitting,
    s=1,
    color="blue",
    label="original",
)
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(
        wavelengths_fitting_angstrom,
        transmission_fitting,
        color="blue",
        label="original",
    )
    ax[2].plot(
        wavelengths_fitting_angstrom, transmission_smooth, color="red", label="smoothed"
    )
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>280</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.01192862</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 6.3114e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1888.55814</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1865.61134</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93260354</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.19167490</td><td style='text-align:left'> 0.15582745</td><td style='text-align:left'>(81.30%)</td><td style='text-align:left'>0.23111032383624416</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.40013012</td><td style='text-align:left'> 0.05710283</td><td style='text-align:left'>(14.27%)</td><td style='text-align:left'>0.24566183024613855</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.53558809</td><td style='text-align:left'> 0.18317938</td><td style='text-align:left'>(34.20%)</td><td style='text-align:left'>0.24147418058214412</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.11838173</td><td style='text-align:left'> 0.06882640</td><td style='text-align:left'>(58.14%)</td><td style='text-align:left'>-0.0153330495839759</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.61220075</td><td style='text-align:left'> 0.00190887</td><td style='text-align:left'>(0.07%)</td><td style='text-align:left'>2.6191199296650693</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00244538</td><td style='text-align:left'> 0.00181180</td><td style='text-align:left'>(74.09%)</td><td style='text-align:left'>0.036463950458768206</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.01045959</td><td style='text-align:left'> 0.00260879</td><td style='text-align:left'>(24.94%)</td><td style='text-align:left'>0.0033819993370662327</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are  ...

# %% [markdown]
# and some times we need to auto bump the Gaussian filter kernel to get a good fit

# %%
bin_data = bin_transmission["2"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = (
    config.analysis.fitting.lambda_min,
    config.analysis.fitting.lambda_max,
)
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (
    wavelengths_angstrom < lambda_max_angstrom
)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color="green", alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color="red", linestyle="--")
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(
    wavelengths_fitting_angstrom,
    transmission_fitting,
    s=1,
    color="blue",
    label="original",
)
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(
        wavelengths_fitting_angstrom,
        transmission_fitting,
        color="blue",
        label="original",
    )
    ax[2].plot(
        wavelengths_fitting_angstrom, transmission_smooth, color="red", label="smoothed"
    )
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-11-08 15:11:19,998 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:19,999 - INFO - Failed fitting with sigma = 19
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>13667</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.01521260</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 8.0490e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1840.89414</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1817.94734</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.90689999</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.38250640</td><td style='text-align:left'> 0.15560762</td><td style='text-align:left'>(40.68%)</td><td style='text-align:left'>0.037493211392917114</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.46469810</td><td style='text-align:left'> 0.05714096</td><td style='text-align:left'>(12.30%)</td><td style='text-align:left'>0.31048506131096976</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.74351110</td><td style='text-align:left'> 0.19178966</td><td style='text-align:left'>(25.80%)</td><td style='text-align:left'>0.3657839905273209</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.20080650</td><td style='text-align:left'> 0.07267635</td><td style='text-align:left'>(36.19%)</td><td style='text-align:left'>-0.06278141559275012</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.61703888</td><td style='text-align:left'> 0.00462649</td><td style='text-align:left'>(0.18%)</td><td style='text-align:left'>2.6163606620214037</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00880166</td><td style='text-align:left'> 0.00409297</td><td style='text-align:left'>(46.50%)</td><td style='text-align:left'>0.045694958064530534</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.00611508</td><td style='text-align:left'> 0.00306689</td><td style='text-align:left'>(50.15%)</td><td style='text-align:left'>0.00259811335617555</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are ...

# %% [markdown]
# unfortunately, some bins has really **low SNR**, even two-step fitting is not sufficient.
# In situations like this (should be rare), we accept defeat and move on

# %%
bin_data = bin_transmission["14"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = (
    config.analysis.fitting.lambda_min,
    config.analysis.fitting.lambda_max,
)
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (
    wavelengths_angstrom < lambda_max_angstrom
)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color="green", alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color="red", linestyle="--")
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(
    wavelengths_fitting_angstrom,
    transmission_fitting,
    s=1,
    color="blue",
    label="original",
)
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(
        wavelengths_fitting_angstrom,
        transmission_fitting,
        color="blue",
        label="original",
    )
    ax[2].plot(
        wavelengths_fitting_angstrom, transmission_smooth, color="red", label="smoothed"
    )
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-11-08 15:11:20,613 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:20,613 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:20,623 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.

# %% [markdown]
# Now let's process all the bins

# %%
# step_0: prepare the lambda range
lambda_min_angstrom = config.analysis.fitting.lambda_min * 1e10
lambda_max_angstrom = config.analysis.fitting.lambda_max * 1e10
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
# step_1: get the reference (zero strain) Bragg edge value
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)
# step_2: setup the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.2},
    "tau": {"min": 0.001, "max": 0.2},
}
# step_3: fitting
fit_results = {}
for key, value in bin_transmission.items():
    wavelengths_angstrom = value["wavelengths"] * 1e10
    transmission = value["transmission"]
    # step_3.1: prepare the fitting range
    mask = (wavelengths_angstrom > lambda_min_angstrom) & (
        wavelengths_angstrom < lambda_max_angstrom
    )
    wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
    transmission_fitting = transmission[mask]
    # step_3.2: fitting a smooth version first to get better initial guess
    # NOTE: eventually we will always get a fit for over-smoothed data, so we need to gradually increase the sigma
    #       although the quality of the initial guess decreases with the increase of sigma
    ratio = 0.10
    fit_success = False
    while not fit_success:
        sigma = int(len(transmission_fitting) * ratio)
        transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
        fit_result_smoothed = fit_bragg_edge_single_pass(
            wavelengths=wavelengths_fitting_angstrom,
            transmission=transmission_smooth,
            initial_parameters=initial_parameters,
            parameter_bounds=parameter_bounds,
        )
        if fit_result_smoothed is None:
            logging.info(f"Failed fitting with sigma = {sigma}")
            ratio += 0.02
            continue
        else:
            fit_success = True
    # step_3.3: fitting
    fit_result = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_fitting,
        initial_parameters=fit_result_smoothed.best_values,
        parameter_bounds=parameter_bounds,
    )
    fit_results[key] = fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-11-08 15:11:21,760 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:22,212 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:22,212 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:23,344 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:24,025 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:24,558 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:24,563 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,563 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:24,583 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,583 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:24,586 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,586 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:24,589 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,589 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:24,591 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,591 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:24,594 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:24,594 - INFO - Failed fitting with sigma = 35
# 2024-11-08 15:11:24,600 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,178 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:25,184 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,184 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:25,188 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,189 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:25,193 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,194 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:25,197 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,197 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:25,471 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,471 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:25,506 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,507 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:25,863 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,864 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:25,869 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,869 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:25,978 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,979 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:25,989 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:25,989 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:26,531 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:26,555 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,555 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:26,559 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,560 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:26,585 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,588 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,588 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:26,591 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,592 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:26,595 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,595 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:26,702 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,702 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:26,712 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:26,712 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:27,336 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:27,336 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:27,882 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:27,895 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:27,896 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,074 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,074 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,092 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,093 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,107 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,107 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,111 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,111 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:28,130 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,130 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,133 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,133 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:28,136 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,136 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:28,138 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,139 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:28,141 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,141 - INFO - Failed fitting with sigma = 35
# 2024-11-08 15:11:28,476 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,477 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:28,482 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,482 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:28,487 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,487 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:28,988 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:28,989 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:29,032 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,033 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:29,057 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,057 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:29,059 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,059 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:29,076 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,076 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:29,079 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,080 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:29,082 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,082 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:29,085 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,085 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:29,088 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,089 - INFO - Failed fitting with sigma = 35
# 2024-11-08 15:11:29,426 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,427 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:29,429 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:29,429 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:29,440 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,297 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,297 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,321 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,321 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,324 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,324 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:30,327 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,327 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:30,335 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,335 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:30,658 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,659 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,682 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,683 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,685 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,685 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:30,688 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,688 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:30,691 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,691 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:30,695 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,696 - INFO - Failed fitting with sigma = 35
# 2024-11-08 15:11:30,725 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,725 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,730 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,730 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:30,844 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,853 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,856 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,856 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:30,938 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:30,939 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,096 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,096 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,113 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,113 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,116 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,117 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:31,197 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,198 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,200 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,200 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:31,203 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,203 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:31,205 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,206 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:31,223 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,223 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,228 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,228 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:31,231 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,232 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:31,244 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,259 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,260 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,383 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,383 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,397 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,398 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,629 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,629 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,661 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,661 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,819 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,819 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,847 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,847 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:31,878 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:31,878 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:32,076 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,077 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:32,265 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,265 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:32,269 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,269 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:32,312 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,312 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:32,465 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,465 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:32,545 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:32,545 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,082 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:33,112 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,112 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,678 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,678 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,813 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,814 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,831 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,831 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,835 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,835 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:33,851 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,851 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,905 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,906 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,909 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,910 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:33,928 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,928 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:33,933 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,933 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:33,938 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:33,938 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:34,453 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,453 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,468 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,469 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,491 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,491 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,493 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,494 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:34,496 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,496 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:34,499 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,499 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:34,566 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,566 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,607 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,608 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,626 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,626 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:34,631 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:34,631 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:35,208 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,208 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,222 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,223 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,225 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,225 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:35,228 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,228 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:35,230 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,231 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:35,248 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,248 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,251 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,251 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:35,267 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,267 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,284 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,284 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,306 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,307 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,315 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,315 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:35,323 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,681 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,681 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,893 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,893 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,914 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,914 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,946 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,946 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:35,949 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,949 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:35,952 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,952 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:35,954 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:35,955 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:36,723 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:36,723 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:36,730 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:36,730 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:36,736 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:36,736 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:36,805 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:36,805 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:36,807 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:36,808 - INFO - Failed fitting with sigma = 23
# ...
# 2024-11-08 15:11:37,404 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:37,405 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:37,408 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:37,408 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:37,412 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:37,412 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:37,952 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:38,281 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,281 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,288 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,288 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:38,322 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,322 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,396 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,397 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,402 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,402 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:38,418 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,419 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,689 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,689 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,770 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,771 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,795 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,796 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:38,799 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:38,799 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:39,044 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:39,044 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:39,049 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:39,049 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:39,621 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:39,629 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:39,630 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:39,634 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:39,635 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:40,177 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:40,199 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,200 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,311 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,311 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,850 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,850 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,853 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,853 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:40,858 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,858 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:40,862 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,863 - INFO - Failed fitting with sigma = 31
# 2024-11-08 15:11:40,880 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,881 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,897 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,897 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,900 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,900 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:40,902 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,902 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:40,918 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,919 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:40,973 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:40,974 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,007 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,007 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,029 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,030 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,032 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,032 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:41,086 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,107 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,664 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-11-08 15:11:41,667 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,668 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,681 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,686 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,686 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,717 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,717 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,794 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,795 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,809 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,810 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,812 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,812 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:41,815 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,816 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:41,826 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,829 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,829 - INFO - Failed fitting with sigma = 19
# 2024-11-08 15:11:41,831 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,831 - INFO - Failed fitting with sigma = 23
# 2024-11-08 15:11:41,834 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,834 - INFO - Failed fitting with sigma = 27
# 2024-11-08 15:11:41,837 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-11-08 15:11:41,837 - INFO - Failed fitting with sigma = 31

# %%
fig, axes = plot_fitting_results_grid(
    fit_results=fit_results,
    bin_transmission=bin_transmission,
    reference_wavelength=lambda_0_angstrom,
)
plt.show()

# %% [markdown]
# now calculate strain

# %%
strain_results = calculate_strain_mapping(
    fit_results=fit_results,
    d0=lambda_0_angstrom / 2.0,
    quality_threshold=0.8,
)

# %%
# Create strain map overlay
fig, ax = plot_strain_map_overlay(
    strain_results=strain_results,
    bin_transmission=bin_transmission,
    integrated_image=np.sum(normalized_data, axis=0).T,
    colormap="viridis",
    interpolation="nearest",
    alpha=0.5,
    # vmin=-0.01,
    # vmax=0.01,
)

# %%
# check if using custom material
if config.analysis.material.custom_material:
    material_name = config.analysis.material.custom_material.name
else:
    material_name = config.analysis.material.element

metadata = {
    "material_name": material_name,
    "d0": lambda_0_angstrom,
    "distance_source_detector": config.analysis.distance_source_detector_in_m,
    "detector_offset": config.analysis.detector_offset_in_us,
}

output_config = OutputFileConfig()

df = save_analysis_results(
    fit_results=fit_results,
    bin_coordinates=bins,
    strain_results=strain_results,
    metadata=metadata,
    output_path="test.csv",
    config=output_config,
)

df
# Out:
# 2024-11-08 15:11:52,989 - INFO - Saved analysis results to test.csv
#     bin_id   x0   y0   x1   y1  row_index  column_index  lambda_hkl  \
# 0        0  140  154  150  164          0             0    2.620366
# 1        1  140  164  150  174          1             0    2.617754
# 2        2  140  174  150  184          2             0    2.617021
# 3        3  140  184  150  194          3             0    2.615161
# 4        4  140  194  150  204          4             0    2.610076
# ..     ...  ...  ...  ...  ...        ...           ...         ...
# 253    264  310  244  320  254          9            17    2.621576
# 254    265  310  254  320  264         10            17    2.620130
# 255    266  310  264  320  274         11            17    2.619567
# 256    268  310  284  320  294         13            17    2.616359
# 257    269  310  294  320  304         14            17    2.617349
#
#      lambda_hkl_err  d_spacing  d_spacing_err    strain  strain_err  \
# 0               NaN   1.310183            NaN  0.051637         NaN
# 1          0.006485   1.308877       0.003243  0.050588    0.002603
# 2               NaN   1.308510            NaN  0.050294         NaN
# 3          0.004339   1.307580       0.002170  0.049548    0.001742
# 4          0.001424   1.305038       0.000712  0.047507    0.000571
# ..              ...        ...            ...       ...         ...
# 253             NaN   1.310788            NaN  0.052122         NaN
# 254        0.000858   1.310065       0.000429  0.051542    0.000344
# 255             NaN   1.309783            NaN  0.051316         NaN
# 256        0.005630   1.308179       0.002815  0.050028    0.002260
# 257        0.001630   1.308674       0.000815  0.050426    0.000654
#
#      r_squared  chi_squared
# 0     0.950547     0.008091
# 1     0.932537     0.011940
# 2     0.906823     0.015225
# 3     0.939595     0.009069
# 4     0.931542     0.010923
# ..         ...          ...
# 253   0.920484     0.012183
# 254   0.935192     0.009694
# 255   0.947131     0.008863
# 256   0.942840     0.008032
# 257   0.944008     0.007970
#
# [258 rows x 15 columns]
