# %% [markdown]
# # Step by step Bragg edge fitting with iBeatles

# %%
import logging
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from scipy.ndimage import gaussian_filter1d
from ibeatles.app.cli import load_data, load_config
from ibeatles.core.processing.normalization import normalize_data
from ibeatles.core.fitting.binning import get_bin_coordinates, get_bin_transmission
from ibeatles.core.material import get_initial_bragg_edge_lambda
from ibeatles.core.fitting.kropff.fitting import fit_bragg_edge_single_pass

# %%
# Set up a custom handler and formatter
handler = logging.StreamHandler()
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
handler.setLevel(logging.INFO)

# Get the root logger and attach the handler
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [handler]  # Replace existing handlers with the custom handler

# %% [markdown]
# ## Data Loading

# %%
# load config
logging.info("Loading config file")
config_file = "../tests/data/json/demo_config.json"
config = load_config(config_file)
logging.info(config)

# load data
logging.info("Loading data")
data_dict = load_data(config)
logging.info(data_dict.keys())
# make local var for raw data, open beam and spectra data
raw_data_dict = data_dict['raw_data']
open_beam_dict = data_dict['open_beam']
spectra_dict = data_dict['spectra']
logging.info(raw_data_dict.keys())
logging.info(open_beam_dict.keys())
logging.info(spectra_dict.keys())
# Out:
# 2024-10-31 11:39:43,042 - INFO - Loading config file
# 2024-10-31 11:39:43,047 - INFO - raw_data=RawData(raw_data_dir=PosixPath('/Users/8cz/github.com/iBeatles/tests/data/ibeatles_data/SNS/SNAP/IPTS-26171/shared/mcp_transfer/Inconel_Sample'), raw_data_extension='.fits') open_beam=OpenBeamData(open_beam_data_dir=PosixPath('/Users/8cz/github.com/iBeatles/tests/data/ibeatles_data/SNS/SNAP/IPTS-26171/shared/mcp_transfer/Inconel_OB'), open_beam_data_extension='.fits') spectra_file_path=None normalization=NormalizationConfig(sample_background=[SampleBackground(x0=10, y0=10, width=50, height=50), SampleBackground(x0=0, y0=0, width=3, height=3)], moving_average=MovingAverage(active=True, dimension='2D', size=KernelSize(y=3, x=3), type=<KernelType.box: 'Box'>), processing_order=<ProcessOrder.moving_average_normalization: 'Moving average, Normalization'>) analysis=AnalysisConfig(material=Material(element='Ni', custom_material=None), pixel_binning=PixelBinning(x0=140, y0=154, width=184, height=150, bins_size=10), fitting=FittingConfig(lambda_min=2.4e-10, lambda_max=2.8e-10, threshold_finder=ThresholdFinder(method='Sliding Average', threshold_width=5), fitting_criteria=FittingCriteria(lambda_hkl={'use': True, 'value': 0.01}, tau={'use': False, 'value': 0.01}, sigma={'use': False, 'value': 0.01}), rejection_criteria=RejectionCriteria(bragg_peak_lambda_min={'use': True, 'value': 0.0}, bragg_peak_lambda_max={'use': True, 'value': 10.0})), strain_mapping=StrainMapping(d0=None, output=None), distance_source_detector_in_m=19.855, detector_offset_in_us=5000.0) output={'normalized_data_dir': PosixPath('/Users/8cz/tmp/ibeatles_dev/normalized'), 'analysis_results_dir': PosixPath('/Users/8cz/tmp/ibeatles_dev/analysis')}
# 2024-10-31 11:39:43,048 - INFO - Loading data
# 2024-10-31 11:39:43,049 - INFO - Loading data...
# 2024-10-31 11:39:52,846 - INFO - dict_keys(['raw_data', 'open_beam', 'spectra'])
# 2024-10-31 11:39:52,847 - INFO - dict_keys(['data', 'metadata', 'file_list', 'folder', 'size'])
# 2024-10-31 11:39:52,847 - INFO - dict_keys(['data', 'metadata', 'file_list', 'folder', 'size'])
# 2024-10-31 11:39:52,847 - INFO - dict_keys(['filename', 'short_filename', 'tof_array', 'counts_array', 'lambda_array'])

# %% [markdown]
# quick sanity check of the spectrum data

# %%
# plot the overall spectra (lambda vs. counts)
lambda_array = spectra_dict["lambda_array"]
counts_array = spectra_dict["counts_array"]

plt.plot(lambda_array, counts_array)
plt.xlabel("Wavelength (m)")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ## Data normalization
#
# We will be using NeuNorm (ibeatles provide a wrapper for NeuNorm) to perform the normalization

# %%
normalized_data, output_path = normalize_data(
    sample_data=raw_data_dict["data"],
    ob_data=open_beam_dict["data"],
    time_spectra=spectra_dict,
    config=config,
    output_folder=config.output["normalized_data_dir"],
)
# Out:
# 2024-10-31 11:39:52,958 - INFO - Starting normalization process
# Loading sample:   0%|          | 0/1435 [00:00<?, ?it/s]
# Loading ob:   0%|          | 0/1435 [00:00<?, ?it/s]
# 2024-10-31 11:39:53,829 - INFO - Applying moving average
# 2024-10-31 11:40:10,658 - INFO - Performing normalization
# 2024-10-31 11:40:12,670 - INFO - Copied time spectra file to /Users/8cz/tmp/ibeatles_dev/normalized/Inconel_Sample_normalized/20210910_Run_52256_InconelPowder_0008_0646026_Spectra.txt

# %% [markdown]
# Sanity check of the normalized data

# %%
# display original and clipped image
img  = normalized_data[0].T
img_clipped = np.array(img)
img_clipped[img > 1.0] = np.nan

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(img, cmap='viridis')
ax[0].set_title("Original Image")
# add colorbar
cbar = plt.colorbar(ax[0].imshow(img, cmap='viridis'), ax=ax[0])
ax[1].imshow(img_clipped, cmap='viridis')
ax[1].set_title("Clipped Image")
# add colorbar
cbar = plt.colorbar(ax[1].imshow(img_clipped, cmap='viridis'), ax=ax[1])

plt.show()

# %% [markdown]
# compute the cumulative distribution for the intensity (transmission) values

# %%
# compute the histogram
hist, bin_edges = np.histogram(img.flatten(), bins=1000, density=True)

# compute the cumulative distribution
cdf = np.cumsum(hist)

# plot the histogram and the cumulative distribution
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].plot(bin_edges[:-1], hist)
ax[0].set_title("Histogram")
ax[0].set_xlabel("Intensity")
ax[0].set_ylabel("Frequency")

ax[1].plot(bin_edges[:-1], cdf)
ax[1].set_title("Cumulative Distribution")
ax[1].set_xlabel("Intensity")
ax[1].set_ylabel("Frequency")

plt.show()

# %% [markdown]
# ## Kropff fitting to locate the Bragg edge

# %%
logging.info(config.analysis.pixel_binning)
# Out:
# 2024-10-31 11:40:13,050 - INFO - x0=140 y0=154 width=184 height=150 bins_size=10

# %%
bins = get_bin_coordinates(
    image_shape=normalized_data[0].shape,
    **config.analysis.pixel_binning.model_dump(),  # to dict for unpacking
)

# %% [markdown]
# Get transmission profile for each bin

# %%
wavelengths = spectra_dict["lambda_array"]
lambda_range = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max

bin_transmission = {}

for i, bin_coord in enumerate(bins):
    wavelengths_bin, transmission_bin = get_bin_transmission(
        images=normalized_data,
        wavelengths=wavelengths,
        bin_coords=bin_coord,
        lambda_range=None,
    )
    bin_transmission[str(i)] = {
        "wavelengths": wavelengths_bin,
        "transmission": transmission_bin,
        "coordinates": bin_coord
    }

# %% [markdown]
# visual inspection of the transmission profiles

# %%
# Normalize the keys for colormap
keys = list(bin_transmission.keys())
norm = mcolors.Normalize(vmin=min(keys), vmax=max(keys))
cmap = cm.viridis

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Plot each curve with color from colormap
for key, value in bin_transmission.items():
    key = int(key)  # Convert key to integer
    color = cmap(norm(key))  # Map the key to a color
    ax.plot(
        value["wavelengths"],
        value["transmission"],
        color=color,
        linewidth=0.5,
        alpha=0.5,
    )

# Label axes
ax.set_xlabel("Wavelength (m)")
ax.set_ylabel("Transmission")

# Add color bar with label
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])  # Required for ScalarMappable
cbar = fig.colorbar(sm, ax=ax)  # Associate color bar with the current axis
cbar.set_label("Bin ID")  # Replace with the appropriate label for your keys

plt.show()

# %% [markdown]
# Now let's isolate one bin and perform a manual fitting

# %%
bin_data_0 = bin_transmission["0"]
wavelengths_m = bin_data_0["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data_0["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=initial_parameters,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# top one shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color='green', alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# bottom one shows the fitting range
fit_result.plot_fit(ax=ax[1])

plt.show()

# print the fitting result
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>395</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.00809122</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 4.2811e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1964.63769</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1941.69089</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.95054661</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.56732929</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.54851446</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.97470754</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.28303060</td><td style='text-align:left'>0.1</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.62036567</td><td style='text-align:left'>2.491702875545156</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00891793</td><td style='text-align:left'>0.01</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.00100087</td><td style='text-align:left'>0.01</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table>

# %% [markdown]
# when the data is (relatively) clean with sufficient SNR, the default single pass fitting will work.
#
# However things becomes slightly more complicated when the data is noisy or when the SNR is low, for instance:

# %%
bin_data_0 = bin_transmission["1"]
wavelengths_m = bin_data_0["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data_0["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=initial_parameters,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# top one shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color='green', alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# bottom one shows the fitting range
# fit_result.plot_fit(ax=ax[1])
ax[1].plot(wavelengths_fitting_angstrom, transmission_fitting)

plt.show()

# print the fitting result
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-10-31 11:40:17,292 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.

# %% [markdown]
# This data is not extremely noisy, but the high frequency noise is making the fitting difficult. Therefore we will have to use a two step fitting approach to deal with this issue.
# - step 1: use low-pass filter (Gaussian) to adaptively reach a smooth representation of the data such that an initial guess can be made
# - step 2: use the initial guess to perform a single pass fitting with the raw data

# %%
bin_data = bin_transmission["1"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color='green', alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(wavelengths_fitting_angstrom, transmission_fitting, s=1, color='blue', label='original')
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(wavelengths_fitting_angstrom, transmission_fitting, color='blue', label='original')
    ax[2].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>280</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.01192862</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 6.3114e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1888.55814</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1865.61134</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93260354</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.19167490</td><td style='text-align:left'> 0.15582745</td><td style='text-align:left'>(81.30%)</td><td style='text-align:left'>0.23111032383624416</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.40013012</td><td style='text-align:left'> 0.05710283</td><td style='text-align:left'>(14.27%)</td><td style='text-align:left'>0.24566183024613855</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.53558809</td><td style='text-align:left'> 0.18317938</td><td style='text-align:left'>(34.20%)</td><td style='text-align:left'>0.24147418058214412</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.11838173</td><td style='text-align:left'> 0.06882640</td><td style='text-align:left'>(58.14%)</td><td style='text-align:left'>-0.0153330495839759</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.61220075</td><td style='text-align:left'> 0.00190887</td><td style='text-align:left'>(0.07%)</td><td style='text-align:left'>2.6191199296650693</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00244538</td><td style='text-align:left'> 0.00181180</td><td style='text-align:left'>(74.09%)</td><td style='text-align:left'>0.036463950458768206</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.01045959</td><td style='text-align:left'> 0.00260879</td><td style='text-align:left'>(24.94%)</td><td style='text-align:left'>0.0033819993370662327</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are  ...

# %% [markdown]
# and some times we need to auto bump the Gaussian filter kernel to get a good fit

# %%
bin_data = bin_transmission["2"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color='green', alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(wavelengths_fitting_angstrom, transmission_fitting, s=1, color='blue', label='original')
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(wavelengths_fitting_angstrom, transmission_fitting, color='blue', label='original')
    ax[2].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-10-31 11:40:17,565 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:17,566 - INFO - Failed fitting with sigma = 19
# <h2>Fit Result</h2> <p>Model: Model(kropff_transmission_model)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>13667</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>196</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>7</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 0.01521260</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 8.0490e-05</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1840.89414</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1817.94734</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.90689999</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>a0</td><td style='text-align:left'>-0.38250640</td><td style='text-align:left'> 0.15560762</td><td style='text-align:left'>(40.68%)</td><td style='text-align:left'>0.037493211392917114</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b0</td><td style='text-align:left'> 0.46469810</td><td style='text-align:left'> 0.05714096</td><td style='text-align:left'>(12.30%)</td><td style='text-align:left'>0.31048506131096976</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>a_hkl</td><td style='text-align:left'> 0.74351110</td><td style='text-align:left'> 0.19178966</td><td style='text-align:left'>(25.80%)</td><td style='text-align:left'>0.3657839905273209</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>b_hkl</td><td style='text-align:left'>-0.20080650</td><td style='text-align:left'> 0.07267635</td><td style='text-align:left'>(36.19%)</td><td style='text-align:left'>-0.06278141559275012</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>bragg_edge_wavelength</td><td style='text-align:left'> 2.61703888</td><td style='text-align:left'> 0.00462649</td><td style='text-align:left'>(0.18%)</td><td style='text-align:left'>2.6163606620214037</td><td style='text-align:left'> 2.40000000</td><td style='text-align:left'> 2.80000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sigma</td><td style='text-align:left'> 0.00880166</td><td style='text-align:left'> 0.00409297</td><td style='text-align:left'>(46.50%)</td><td style='text-align:left'>0.045694958064530534</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>tau</td><td style='text-align:left'> 0.00611508</td><td style='text-align:left'> 0.00306689</td><td style='text-align:left'>(50.15%)</td><td style='text-align:left'>0.00259811335617555</td><td style='text-align:left'> 1.0000e-03</td><td style='text-align:left'> 0.10000000</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are ...

# %% [markdown]
# unfortunately, some bins has really **low SNR**, even two-step fitting is not sufficient.
# In situations like this (should be rare), we accept defeat and move on

# %%
bin_data = bin_transmission["14"]
wavelengths_m = bin_data["wavelengths"]
wavelengths_angstrom = wavelengths_m * 1e10
transmission = bin_data["transmission"]

# parsing the config
lambda_min_m, lambda_max_m = config.analysis.fitting.lambda_min, config.analysis.fitting.lambda_max
lambda_min_angstrom = lambda_min_m * 1e10
lambda_max_angstrom = lambda_max_m * 1e10

# get the reference (zero strain) Bragg edge value
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)

# fitting
# step_0: need to zoom in to the lambda range as the shape function is not defined outside the range
mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
transmission_fitting = transmission[mask]
# step_1: prepare the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.1},
    "tau": {"min": 0.001, "max": 0.1},
}
# step_2: fitting a smooth curve
# starting with sigma as 15% of the data length, gradually increase if the fitting if failing
ratio = 0.10
fit_success = False
while not fit_success:
    sigma = int(len(transmission_fitting) * ratio)
    transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
    fit_result_smoothed = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_smooth,
        initial_parameters=initial_parameters,
        parameter_bounds=parameter_bounds,
    )
    if fit_result_smoothed is None:
        logging.info(f"Failed fitting with sigma = {sigma}")
        ratio += 0.02
        continue
    else:
        fit_success = True
# step_3: fitting the original data with the smoothed curve as the initial guess
fit_result = fit_bragg_edge_single_pass(
    wavelengths=wavelengths_fitting_angstrom,
    transmission=transmission_fitting,
    initial_parameters=fit_result_smoothed.best_values,
    parameter_bounds=parameter_bounds,
)

# viaulization
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
# left shows the full range
ax[0].plot(wavelengths_angstrom, transmission)
# place a block to indicate teh fitting range
ax[0].axvspan(lambda_min_angstrom, lambda_max_angstrom, color='green', alpha=0.5)
# use vertical red line to indicate the reference Bragg edge
ax[0].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
ax[0].set_xlabel("Wavelength (Angstrom)")
ax[0].set_ylabel("Transmission")
# middle shows the fitting of smoothed curve
fit_result_smoothed.plot_fit(ax=ax[1], datafmt=".")
ax[1].scatter(wavelengths_fitting_angstrom, transmission_fitting, s=1, color='blue', label='original')
# ax[1].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
# right shows the final fitting result
if fit_result is not None:
    fit_result.plot_fit(ax=ax[2], datafmt=".")
else:
    # if the fitting failed, plot the raw data and the smoothed curve
    ax[2].plot(wavelengths_fitting_angstrom, transmission_fitting, color='blue', label='original')
    ax[2].plot(wavelengths_fitting_angstrom, transmission_smooth, color='red', label='smoothed')
ax[2].set_xlabel("Wavelength (Angstrom)")
ax[2].set_ylabel("Transmission")

plt.show()

# fit_result_smoothed
fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-10-31 11:40:18,181 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:18,182 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:18,191 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.

# %% [markdown]
# Now let's process all the bins

# %%
# step_0: prepare the lambda range
lambda_min_angstrom = config.analysis.fitting.lambda_min * 1e10
lambda_max_angstrom = config.analysis.fitting.lambda_max * 1e10
lambda_range_angstrom = lambda_min_angstrom, lambda_max_angstrom
# step_1: get the reference (zero strain) Bragg edge value
lambda_0_angstrom = get_initial_bragg_edge_lambda(
    material_config=config.analysis.material,
    lambda_range=lambda_range_angstrom,
)
# step_2: setup the initial guess and bounds
initial_parameters = {
    "a0": 0.1,
    "b0": 0.1,
    "a_hkl": 0.1,
    "b_hkl": 0.1,
    "bragg_edge_wavelength": lambda_0_angstrom,  # use the reference Bragg edge as the initial guess
    "sigma": 0.01,
    "tau": 0.01,
}
parameter_bounds = {
    "bragg_edge_wavelength": {
        "min": lambda_min_angstrom,
        "max": lambda_max_angstrom,
    },
    "sigma": {"min": 0.001, "max": 0.2},
    "tau": {"min": 0.001, "max": 0.2}
}
# step_3: fitting
fit_results = {}
for key, value in bin_transmission.items():
    wavelengths_angstrom = value["wavelengths"] * 1e10
    transmission = value["transmission"]
    # step_3.1: prepare the fitting range
    mask = (wavelengths_angstrom > lambda_min_angstrom) & (wavelengths_angstrom < lambda_max_angstrom)
    wavelengths_fitting_angstrom = wavelengths_angstrom[mask]
    transmission_fitting = transmission[mask]
    # step_3.2: fitting a smooth version first to get better initial guess
    # NOTE: eventually we will always get a fit for over-smoothed data, so we need to gradually increase the sigma
    #       although the quality of the initial guess decreases with the increase of sigma
    ratio = 0.10
    fit_success = False
    while not fit_success:
        sigma = int(len(transmission_fitting) * ratio)
        transmission_smooth = gaussian_filter1d(transmission_fitting, sigma=sigma)
        fit_result_smoothed = fit_bragg_edge_single_pass(
            wavelengths=wavelengths_fitting_angstrom,
            transmission=transmission_smooth,
            initial_parameters=initial_parameters,
            parameter_bounds=parameter_bounds,
        )
        if fit_result_smoothed is None:
            logging.info(f"Failed fitting with sigma = {sigma}")
            ratio += 0.02
            continue
        else:
            fit_success = True
    # step_3.3: fitting
    fit_result = fit_bragg_edge_single_pass(
        wavelengths=wavelengths_fitting_angstrom,
        transmission=transmission_fitting,
        initial_parameters=fit_result_smoothed.best_values,
        parameter_bounds=parameter_bounds,
    )
    fit_results[key] = fit_result
# Out:
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   self.lattice = float(_metadata[0])
# /Users/8cz/micromamba/envs/ibeatles/lib/python3.11/site-packages/neutronbraggedge/material_handler/retrieve_material_metadata.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   _full_crystal_str = _metadata[1]
# 2024-10-31 11:40:19,334 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:19,787 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:19,788 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:21,001 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:21,671 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:22,214 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:22,219 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,220 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:22,242 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,242 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:22,245 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,246 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:22,248 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,249 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:22,251 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,251 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:22,254 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,254 - INFO - Failed fitting with sigma = 35
# 2024-10-31 11:40:22,263 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,880 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:22,886 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,886 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:22,890 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,891 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:22,895 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,896 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:22,899 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:22,900 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:23,211 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,212 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:23,249 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,250 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:23,627 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,628 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:23,633 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,634 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:23,754 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,754 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:23,766 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:23,767 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:24,305 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:24,328 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,328 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:24,334 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,334 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:24,362 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,364 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,365 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:24,368 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,368 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:24,372 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,372 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:24,492 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,492 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:24,502 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:24,503 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:25,113 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,114 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,652 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:25,667 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,667 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,870 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,870 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,890 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,890 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,905 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,906 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,910 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,910 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:25,932 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,932 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:25,935 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,935 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:25,938 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,939 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:25,941 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,942 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:25,945 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:25,945 - INFO - Failed fitting with sigma = 35
# 2024-10-31 11:40:26,285 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,285 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:26,291 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,291 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:26,297 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,297 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:26,829 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,829 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:26,879 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,879 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:26,906 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,906 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:26,909 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,909 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:26,928 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,929 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:26,932 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,932 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:26,935 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,935 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:26,938 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,939 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:26,943 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:26,943 - INFO - Failed fitting with sigma = 35
# 2024-10-31 11:40:27,307 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:27,307 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:27,310 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:27,311 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:27,323 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,144 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,144 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,172 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,172 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,175 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,175 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:28,178 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,178 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:28,186 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,187 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:28,527 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,527 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,552 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,552 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,555 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,555 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:28,558 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,558 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:28,561 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,562 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:28,567 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,567 - INFO - Failed fitting with sigma = 35
# 2024-10-31 11:40:28,601 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,602 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,606 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,607 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:28,737 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,746 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,750 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,750 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,841 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,841 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:28,996 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:28,997 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,016 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,017 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,088 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,089 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:29,186 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,187 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,190 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,190 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:29,193 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,193 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:29,196 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,197 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:29,215 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,216 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,221 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,222 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:29,226 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,226 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:29,239 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,256 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,256 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,393 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,394 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,410 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,410 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,641 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,642 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,676 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,676 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,796 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,796 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,823 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,824 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:29,854 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:29,854 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:30,054 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,054 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:30,253 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,254 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:30,258 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,258 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:30,303 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,303 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:30,456 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,456 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:30,537 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:30,537 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,104 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:31,137 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,137 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,748 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,749 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,878 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,879 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,896 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,897 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,900 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,901 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:31,919 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,919 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,974 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,975 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:31,978 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,979 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:31,998 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:31,999 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,003 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,003 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:32,010 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,010 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:32,547 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,547 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,563 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,564 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,586 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,586 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,588 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,589 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:32,593 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,593 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:32,596 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,596 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:32,671 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,672 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,721 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,721 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,742 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,742 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:32,747 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:32,747 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:33,346 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,347 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,360 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,361 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,364 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,364 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:33,367 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,367 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:33,371 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,371 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:33,392 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,392 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,395 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,396 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:33,413 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,413 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,431 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,431 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,454 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,454 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:33,464 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,464 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:33,474 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,825 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:33,826 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,052 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,052 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,074 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,074 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,113 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,114 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,116 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,117 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:34,120 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,120 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:34,122 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,123 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:34,892 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,892 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,899 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,899 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:34,905 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,905 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:34,976 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,976 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:34,979 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:34,979 - INFO - Failed fitting with sigma = 23
# ...
# 2024-10-31 11:40:35,580 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:35,581 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:35,584 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:35,584 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:35,589 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:35,589 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:36,192 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:36,511 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,511 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:36,518 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,518 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:36,554 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,554 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:36,638 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,638 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:36,644 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,644 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:36,663 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,663 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:36,948 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:36,949 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:37,035 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,036 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:37,064 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,065 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:37,068 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,068 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:37,319 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,320 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:37,325 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,325 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:37,888 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:37,896 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,897 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:37,901 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:37,902 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:38,487 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:38,509 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:38,510 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:38,625 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:38,625 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,169 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,170 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,173 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,174 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:39,179 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,179 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:39,185 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,185 - INFO - Failed fitting with sigma = 31
# 2024-10-31 11:40:39,204 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,204 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,222 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,223 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,225 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,225 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:39,228 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,228 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:39,245 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,245 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,302 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,302 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,337 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,337 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,362 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,363 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:39,365 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,365 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:39,419 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:39,440 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,066 - WARNING - Fit completed but may not be optimal: Tolerance seems to be too small. Could not estimate error-bars.
# 2024-10-31 11:40:40,070 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,070 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,084 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,088 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,088 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,121 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,121 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,144 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,145 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,162 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,162 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,165 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,165 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:40,169 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,169 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:40,181 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,184 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,184 - INFO - Failed fitting with sigma = 19
# 2024-10-31 11:40:40,186 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,187 - INFO - Failed fitting with sigma = 23
# 2024-10-31 11:40:40,190 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,190 - INFO - Failed fitting with sigma = 27
# 2024-10-31 11:40:40,193 - WARNING - Fitting failed: The model function generated NaN values and the fit aborted! Please check your model function and/or set boundaries on parameters where applicable. In cases like this, using "nan_policy='omit'" will probably not work.
# 2024-10-31 11:40:40,193 - INFO - Failed fitting with sigma = 31

# %%
# visualize the fitting results for all bins in a grid
n_rows = 25
n_cols = 10
fig, ax = plt.subplots(n_rows, n_cols, figsize=(50, 50))
for i, (key, fit_result) in enumerate(fit_results.items()):
    row = i // n_cols
    col = i % n_cols

    ax[row, col].set_title(f"Bin {key}")

    if fit_result:
        # plot the fitting results
        fit_result.plot_fit(ax=ax[row, col], datafmt=".") # plot the fitting result
        # add a vertical line to indicate the reference Bragg edge
        ax[row, col].axvline(x=lambda_0_angstrom, color='red', linestyle='--')
        # add a vertical line to indicate the fitted Bragg edge
        ax[row, col].axvline(x=fit_result.best_values["bragg_edge_wavelength"], color='green', linestyle='--')
        # for all subplots expect the first one
        # turn off axis 
        # turn off legend
        if i != 0:
            ax[row, col].axis('off')
        ax[row, col].legend().set_visible(False)
    else:
        ax[row, col].axis('off')

    # stop if we run out of place to hold figure
    if i == n_rows * n_cols - 1:
        break

# tight layout
plt.tight_layout()
